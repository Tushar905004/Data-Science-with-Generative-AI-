# %%
# Robot 1

def movement_1():
  print("Its Robot 1")


def fire_detection_1():
  print("Its Robot 1")


def wheel_control_1():
  print("Its Robot 1")


## Robot 2

def movement_2():
  print("Its Robot 2")


def fire_detection_2():
  print("Its Robot 2")


def wheel_control_2():
  print("Its Robot 2")

# %%
movement_1()
# Out:
# Its Robot 1

# %%
movement_2()
# Out:
# Its Robot 2

# %% [markdown]
# # OOP

# %%
# using OOP

class Robot:

  def __init__(self, robot_number):
    self.robot_number = robot_number

  def movement(self):
    print(f"Its Robot {self.robot_number}")


  def fire_detection(self):
    print(f"Its Robot {self.robot_number}")

  def wheel_controll(self):
    print(f"Its Robot {self.robot_number}")


  def ai_intelligence(self):
    print(f"Its Robot {self.robot_number}")

# %%
robot1 = Robot(robot_number = 1)

# %%
robot1.movement()
# Out:
# Its Robot 1

# %%
robot2 = Robot(robot_number = 2)

# %%
robot2.movement()
# Out:
# Its Robot 2

# %%
robot3 = Robot(robot_number = 3)
robot3.movement()
# Out:
# Its Robot 3

# %%
robot2.ai_intelligence()
# Out:
# Its Robot 2

# %% [markdown]
# # Class vs Object

# %%
L = [1,2,3,4]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2137908251.py in <cell line: 0>()
#       1 L = [1,2,3,4]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
S = "Bappy"
S.append("F")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-401394919.py in <cell line: 0>()
#       1 S = "Bappy"
# ----> 2 S.append("F")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
a = 66
a[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2471444523.py in <cell line: 0>()
#       1 a = 66
# ----> 2 a[0] = 1
#
# TypeError: 'int' object does not support item assignment

# %%
i = int()

# %%
L = [1,2,3,4]
print(type(L))
# Out:
# <class 'list'>

# %%
S = "inception"
print(type(S))
# Out:
# <class 'str'>

# %%
a = 66

print(type(a))
# Out:
# <class 'int'>

# %%
samsung = mobile()
iphone = mobile()
Vivo = mobile()

# %%
bmw = Car()
audi = Car()

# %%
horse = animal()

# %% [markdown]
# ATM Machine
